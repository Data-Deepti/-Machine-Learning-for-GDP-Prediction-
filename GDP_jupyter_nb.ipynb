# %% [markdown]
# **importing libraries : numpy , pandas ,sci-kit learn**

# %%
import numpy as np 
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# **loading GDP data (source: OGD Platform India)**

# %%
df = pd.read_csv (r'C:\Users\Deepti Anand\Desktop\GDP_.csv' , encoding='unicode_escape')

# %% [markdown]
# **EDA(Exploratory Data Analysis)**

# %%
df.head(2)
# Out:
#          Quarters  Agriculture_forestry_fishing    mining  manufacturing  \
# 0    2011-12 - Q1                     323221.72  64670.25      350857.05
# 1    2011-12 - Q2                     270231.38  55462.63      329936.53
#
#    electricity  construction  trade_services  financial_realestate  \
# 0     44661.97     182218.75       330069.72             395102.00
# 1     46631.13     189095.78       337631.45             407657.04
#
#    publicadministration_defence  GVA_basic_price  ...       GFCF       CIS  \
# 0                     225668.84       1916470.30  ...  682095.08  51753.98
# 1                     263656.97       1900302.91  ...  722663.54  48668.05
#
#    valuables    Exports    Imports  discrepencies       GDP__  Unnamed: 19  \
# 0   55260.05  493074.88  626234.56       -4379.31  2043496.29          NaN
# 1   65317.85  503937.31  636896.39      -49533.58  2029469.17          NaN
#
#    Unnamed: 20  Unnamed: 21
# 0          NaN          NaN
# ...

# %%
df.describe()
# Out:
#        Agriculture_forestry_fishing         mining  manufacturing  \
# count                  4.500000e+01      45.000000      45.000000
# mean                   6.610161e+05   85701.441556  578253.980000
# std                    2.448926e+05   25647.815369  157765.759364
# min                    2.702314e+05   55462.630000  329936.530000
# 25%                    4.855619e+05   68977.190000  435194.660000
# 50%                    6.404706e+05   78868.310000  575851.610000
# 75%                    7.934731e+05   95040.280000  698446.430000
# max                    1.294054e+06  174255.150000  933200.410000
#
#          electricity   construction  trade_services  financial_realestate  \
# count      45.000000      45.000000    4.500000e+01          4.500000e+01
# mean    95126.214889  289272.289333    6.390577e+05          7.508050e+05
# std     33899.314577   83740.836516    1.987660e+05          2.659960e+05
# min     44661.970000  170899.250000    3.300697e+05          3.430649e+05
# ...

# %%
pd.isnull(df).sum()
# Out:
# Quarters                         0
# Agriculture_forestry_fishing     0
# mining                           0
# manufacturing                    0
# electricity                      0
# construction                     0
# trade_services                   0
# financial_realestate             0
# publicadministration_defence     0
# GVA_basic_price                  0
# GFCE                             0
# PFCE                             0
# GFCF                             0
# CIS                              0
# valuables                        0
# Exports                          0
# Imports                          0
# discrepencies                    0
# GDP__                            0
# Unnamed: 19                     45
# Unnamed: 20                     45
# Unnamed: 21                     44
# dtype: int64

# %% [markdown]
# **Preparing Data**

# %%
x = df[['Agriculture_forestry_fishing'  ,'mining' ,'manufacturing' ,'electricity' ,'construction' ,'trade_services','financial_realestate' ,'publicadministration_defence' ,'GVA_basic_price','GFCF' ,'PFCE','GFCF' ,'CIS','valuables','Exports' ,'Imports', 'discrepencies']]

# %%
x
# Out:
#     Agriculture_forestry_fishing     mining  manufacturing  electricity  \
# 0                      323221.72   64670.25      350857.05     44661.97
# 1                      270231.38   55462.63      329936.53     46631.13
# 2                      505545.34   65815.18      334726.67     47957.24
# 3                      402948.88   75087.31      394465.31     47417.66
# 4                      360094.46   75789.47      374606.43     54330.44
# 5                      302960.79   59898.66      395938.88     52470.72
# 6                      557596.77   70446.72      377768.42     54453.30
# 7                      454454.48   79707.16      424523.17     54095.19
# 8                      407712.55   70645.48      413130.91     62946.29
# 9                      350835.20   63145.10      424394.52     65066.08
# 10                     670113.18   74589.20      416194.28     64910.78
# 11                     497710.94   87414.56      459731.89     67231.45
# ...

# %%
y=df['GDP__']
y
# Out:
# 0     2043496.29
# 1     2029469.17
# 2     2244852.23
# 3     2418511.13
# 4     2313203.09
# 5     2356953.27
# 6     2548377.83
# 7     2725478.91
# 8     2565374.45
# 9     2686203.23
# 10    2921070.04
# 11    3060874.14
# 12    2914393.22
# 13    3053982.03
# 14    3184917.06
# 15    3314666.80
# 16    3243543.36
# 17    3355884.42
# 18    3476632.47
# 19    3695813.63
# 20    3639774.61
# 21    3754117.03
# 22    3875006.70
# 23    4122770.68
# 24    4008915.96
# 25    4157246.35
# 26    4339193.52
# 27    4584686.00
# 28    4569369.11
# 29    4656017.01
# 30    4872998.34
# 31    4801283.99
# 32    4942455.14
# 33    4861652.38
# 34    5130411.60
# 35    5140336.68
# 36    3873443.40
# 37    4721818.87
# 38    5448542.27
# 39    5757109.45
# 40    5126789.26
# 41    5620166.01
# 42    6302446.53
# 43    6615235.20
# 44    6494736.35
# Name: GDP__, dtype: float64

# %% [markdown]
# **Splitting Data**

# %%
x_train,x_test,y_train,y_test = train_test_split (x,y,test_size=0.2 ,random_state= 40)

# %%
x_train
# Out:
#     Agriculture_forestry_fishing     mining  manufacturing  electricity  \
# 28                     686739.32   94249.68      676170.09    112151.65
# 18                     721066.22   68977.19      506026.74     81633.54
# 34                    1085522.02   85975.06      649321.57    118638.27
# 29                     591790.48   79982.98      704495.01    116805.34
# 24                     620726.62   82157.28      588489.12    107019.58
# 2                      505545.34   65815.18      334726.67     47957.24
# 5                      302960.79   59898.66      395938.88     52470.72
# 13                     404350.00   68894.15      476473.81     71640.89
# 30                     957922.19   95524.70      685106.84    112012.81
# 38                    1180832.63   78868.31      710550.28    129362.00
# 23                     658690.20  107420.53      626923.16     89245.00
# 3                      402948.88   75087.31      394465.31     47417.66
# ...

# %%
x_test
# Out:
#     Agriculture_forestry_fishing     mining  manufacturing  electricity  \
# 25                     551157.19   67314.83      638557.61    107508.11
# 22                     801318.30   76935.01      554949.63     88828.72
# 36                     782412.53   65417.61      453728.48    115605.32
# 40                     847041.93  109284.78      749345.56    128982.35
# 4                      360094.46   75789.47      374606.43     54330.44
# 44                     994817.55  174255.15      866133.72    174750.49
# 39                     951069.29  116168.93      846710.14    138632.69
# 16                     499370.09   90269.16      530751.51     83639.89
# 11                     497710.94   87414.56      459731.89     67231.45
#
#     construction  trade_services  financial_realestate  \
# 25     281258.11       675948.07             914863.48
# 22     274360.34       619241.88             619110.18
# 36     170899.25       425389.30            1038123.21
# ...

# %% [markdown]
# **Initialize and Fit the model**

# %%
model=LinearRegression()
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Evaluating the model and checking for it's Accuracy**

# %%
y_pred=model.predict(x_test)

# %%
model.score(x_train,y_train)
# Out:
# 0.9997622765014584

# %%
model.score(x_test,y_test)
# Out:
# 0.9965567803196497

# %%
mse = metrics.mean_squared_error(y_test, y_pred)
r_squared = metrics.r2_score(y_test, y_pred)

# %%
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r_squared}')
# Out:
# Mean Squared Error: 5560683293.738281
# R-squared: 0.9965567803196497
